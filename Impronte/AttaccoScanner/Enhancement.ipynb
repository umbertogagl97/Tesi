# %% [markdown]
# <a href="https://colab.research.google.com/github/umbertogagl97/Tesi/blob/main/Impronte/AttaccoScanner/Enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Init**

# %% [markdown]
# ##Import ART

# %%
#importa ART
# !pip install adversarial-robustness-toolbox
# Out:
# Collecting adversarial-robustness-toolbox
#   Downloading adversarial_robustness_toolbox-1.8.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 9.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (4.62.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.15.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.19.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (57.4.0)
# Collecting numba>=0.53.1
#   Downloading numba-0.54.1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 29.7 MB/s
# Requirement already satisfied: scikit-learn<1.1.0,>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.0.1)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 1.6 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<1.1.0,>=0.22.2->adversarial-robustness-toolbox) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<1.1.0,>=0.22.2->adversarial-robustness-toolbox) (1.1.0)
# Installing collected packages: llvmlite, numba, adversarial-robustness-toolbox
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# Successfully installed adversarial-robustness-toolbox-1.8.1 llvmlite-0.37.0 numba-0.54.1

# %% [markdown]
# ##Import librerie

# %%
import torch
import numpy as np
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms

# %% [markdown]
# ##Import LDART

# %%
# !pip install git+https://github.com/umbertogagl97/LivDet_art.git
# Out:
# Collecting git+https://github.com/umbertogagl97/LivDet_art.git
#   Cloning https://github.com/umbertogagl97/LivDet_art.git to /tmp/pip-req-build-473ixxhe
#   Running command git clone -q https://github.com/umbertogagl97/LivDet_art.git /tmp/pip-req-build-473ixxhe
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from LivDet-ART==0.0.1) (1.19.5)
# Building wheels for collected packages: LivDet-ART
#   Building wheel for LivDet-ART (setup.py) ... done
#   Created wheel for LivDet-ART: filename=LivDet_ART-0.0.1-py3-none-any.whl size=19330 sha256=55ac54a056a61be304715cb869f86ec547912bbdbc26b9cfd7bc2a76f7dd9276
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w763iajo/wheels/00/53/f6/1a9221b6c8999525e0a7ad4416ed7ce2ed105427f3bfb7b2d4
# Successfully built LivDet-ART
# Installing collected packages: LivDet-ART
# Successfully installed LivDet-ART-0.0.1

# %%
from ldart.utils import *

# %% [markdown]
# ##Check device

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 1.10.0+cu111
# True
# Tesla P100-PCIE-16GB
# cuda:0

# %% [markdown]
# ##Def path

# %%
#scanner
scanner_name = 'GreenBit'

#load modello
path_model = F"/content/gdrive/My Drive/Scanner/{scanner_name}" 

#dataset
pathTestset=F'/content/gdrive/MyDrive/Dataset_impronte/test/{scanner_name}'

#predizioni testset originale
pd_preds=F'/content/gdrive/MyDrive/Dataset_impronte/test/Preds_value/{scanner_name}_con_normalize.xlsx'

# %% [markdown]
# ##Collegamento google drive

# %%
#collegamento google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #enhanc

# %%
# !pip install fingerprint_enhancer
# Out:
# Collecting fingerprint_enhancer
#   Downloading fingerprint_enhancer-0.0.12.tar.gz (7.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fingerprint_enhancer) (1.19.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from fingerprint_enhancer) (4.1.2.30)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from fingerprint_enhancer) (1.4.1)
# Building wheels for collected packages: fingerprint-enhancer
#   Building wheel for fingerprint-enhancer (setup.py) ... done
#   Created wheel for fingerprint-enhancer: filename=fingerprint_enhancer-0.0.12-py3-none-any.whl size=8059 sha256=0357b485980bf6bd998fae9a805897e5c1de675323779db3a0a5fde2b04781b1
#   Stored in directory: /root/.cache/pip/wheels/c1/10/92/54ee2fcda0ca17304e47e2bc2e20542a6c92fbfc668c6aeba7
# Successfully built fingerprint-enhancer
# Installing collected packages: fingerprint-enhancer
# Successfully installed fingerprint-enhancer-0.0.12

# %%
import fingerprint_enhancer 
def enhanc(img,size_init): 
  '''
  img: ndarray nxmx3
  size_init: dim img (n,m)
  return: img_en 1x3xnxm
  '''
  #img=img.transpose(1,2,0)
  #cv2_imshow(img*255)
  out = fingerprint_enhancer.enhance_Fingerprint(img) 
  out=out/255
  out=1-out

  img=np.zeros([3,size_init[0],size_init[1]])
  for i in range(3):
    img[i,:,:]=out
  #cv2_imshow(img.transpose(1,2,0)*255)
  img=torch.Tensor(img).unsqueeze_(0)
  m=compute_mask(x_print_adv)
  #cv2_imshow(m*255)
  return torch.Tensor(np.where(m == 0.0, 1, img))

# %% [markdown]
# #**Dataset**

# %% [markdown]
# ##Caricamento dataset

# %%
test_dataset = datasets.ImageFolder(pathTestset,transform=transf_load)
dim_set=len(test_dataset)
print(dim_set)
# Out:
# 2500

# %% [markdown]
# ##Dataloader

# %%
testgen=torch.utils.data.DataLoader(test_dataset, pin_memory=True, batch_size=1,num_workers=2)

# %% [markdown]
# ##Nomi classi

# %%
classes_name=test_dataset.classes
class_number=len(classes_name)
print(classes_name)
print(class_number)
#del test_dataset
# Out:
# ['Live', 'Spoof']
# 2

# %% [markdown]
# ##Min Max dataset

# %%
a,_=next(iter(testgen))
_min,_max=torch.min(a),torch.max(a)
print(_min,_max)
# Out:
# tensor(0.0706) tensor(1.)

# %% [markdown]
# ##Transf_init

# %%
size_init=np.array(a.shape[2:4])
transf_init=transforms.Resize(size=(size_init[0],size_init[1]),interpolation=InterpolationMode.NEAREST)

# %% [markdown]
# #**Riduzione dataset**

# %%
test_dataset.samples=test_dataset.samples[1500:1501]

dim_set=len(test_dataset)
print(dim_set)
# Out:
# 1

# %% [markdown]
# # **Creazione modello**
#
# > non ho bloccato i parametri inferiori e sbloccato quelli del classificatore, vedi se funziona

# %% [markdown]
# ##Load model pre-trained

# %%
if scanner_name=='DigitalPersona':
  model = models.densenet201(pretrained=True,progress=True)
else: model = models.vgg19(pretrained=True,progress=True)

#print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %% [markdown]
# ##Aggiunta classificatore

# %%
if scanner_name=='DigitalPersona':
  model.classifier=nn.Linear(1920,2) #per densenet201
else: model.classifier[6]=nn.Linear(4096,2) #per vgg19


#print(model)

# %% [markdown]
# ##Load pesi

# %%
model.load_state_dict(torch.load(path_model))#,map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # **Esecuzione**

# %% [markdown]
# ##Creazione classificatore ART Pytorch

# %%
from art.estimators.classification import PyTorchClassifier

classifier = PyTorchClassifier(
    model=model,
    clip_values=(_min,_max),
    loss=nn.CrossEntropyLoss(),
    optimizer=optim.Adam(model.classifier.parameters(),lr=1e-5),
    input_shape=(3, 224, 224),
    nb_classes=class_number
)

# %% [markdown]
# ##Attacco

# %%
from ldart.attacks.IFGM import IterativeFastGradientMethod
from ldart.attacks.DeepFoolMultiOver import DeepFool_mod
from ldart.attacks.AutoPGD_Mod import AutoProjectedGradientDescent_mod
from art.utils import to_categorical
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import random
import time

# Digital Persona:
#attack = IterativeFastGradientMethod(estimator=classifier, eps=10000,eps_step=0.1,class_target=classes_name.index('Live'),max_iter=100,confidence=0.7)
#attack = AutoProjectedGradientDescent_mod(classifier, eps=100,eps_step=10,nb_random_init=2,class_target=classes_name.index('Live'),max_iter=25,confidence=0.7,verbose=False,norm=2)
#attack = DeepFool_mod(classifier, epsilon=200,max_iter=50,nb_grads=2,class_target=classes_name.index('Live'),confidence=0.7,max_over=50,verbose=False)

#Altri scanner:
#attack = IterativeFastGradientMethod(estimator=classifier, eps=10000,eps_step=0.0005,class_target=classes_name.index('Live'),max_iter=500,confidence=0.8)
#attack = AutoProjectedGradientDescent_mod(classifier, eps=0.1,eps_step=0.05,nb_random_init=5,class_target=classes_name.index('Live'),max_iter=50,confidence=0.95,verbose=False)#,norm=2)
attack = DeepFool_mod(classifier, epsilon=0.1,max_iter=50,nb_grads=2,class_target=classes_name.index('Live'),confidence=0.95,max_over=50,verbose=False)

list_print=sorted(random.sample(range(dim_set),1))

x_print=[]
y_print=[]
x_print_adv=[] 
y_print_adv=[] 
perturb_print=[]
Test_p = pd.DataFrame()
model.eval()
model.cuda()
# starting time
start = time.time()
i=0
for input,label in testgen:
  i+=1

  sys.stdout.write("\rElem: {0}/{1}".format(i,len(testgen)))
  sys.stdout.flush()

  y_test=np.array((to_categorical(label.numpy(),2)))
  x_test=np.array(input.numpy())
  #cv2.imwrite("img_orig.png",x_test[0].transpose(1,2,0)*255)

  x_test_adv=attack.generate(x=np.array(img_en),y=y_test)
  perturb=compute_perturb(x_test[0],x_test_adv[0],transf_init)

  #x_test_adv=x_test_adv[0,:,:,:]
  #x_test_adv=(x_test_adv-np.min(x_test_adv))/(np.max(x_test_adv)-np.min(x_test_adv))
  
  x_test_adv=torch.Tensor(x_test_adv)
  #x_test_adv=x_test_adv.unsqueeze_(0)
  
  if x_test_adv.shape[2]==224:
    x_test_adv=transf_init(x_test_adv)

  pred,probabilities,_=test_average(classifier,x_test_adv,transf_init)
  Test_p = Test_p.append({'real': classes_name[int(label)] ,
                          'predicted': classes_name[pred], #qui metti pred
                          'prob_live': round(probabilities[0],4),
                          'prob_spoof': round(probabilities[1],4)},ignore_index = True)

  #print
  if i-1 in list_print:
    x_print.append(x_test[0])
    x_print_adv.append(x_test_adv[0].numpy())
    y_print.append(y_test)
    y_print_adv.append(probabilities)
    perturb_print.append(perturb)

# end time
end = time.time()

x_print=np.array(x_print)
y_print=np.array(y_print)
x_print_adv=np.array(x_print_adv)
y_print_adv=np.array(y_print_adv)
perturb_print=np.array(perturb_print)

# total time taken
import datetime
time_exe=int(end - start)
time_exe=datetime.timedelta(seconds=time_exe)

print(f"\nRuntime of the program is {time_exe}")
# Out:
# Elem: 1/1
# Runtime of the program is 0:00:07

# %% [markdown]
# ##Testing
#
# > Trasforma i due testing in una funzione e richiamala due volte

# %% [markdown]
# ###Print accuracy test orig from file & load pd

# %%
Test_orig=pd.read_excel(pd_preds)
print_acc(Test_orig)

# %% [markdown]
# ###Testing immagini spoof predette live prima e dopo

# %% [markdown]
# ####Accuracy adv

# %%
print_acc(Test_p)
# Out:
# Accuracy: 0.13
# Shape dataframe: (1500, 4)

# %% [markdown]
# ####Spoof

# %% [markdown]
# prima

# %%
accuracy_class('Spoof',Test_orig)

# %% [markdown]
# dopo

# %%
accuracy_class('Spoof',Test_p)

# %% [markdown]
# ####Live

# %% [markdown]
# prima

# %%
accuracy_class('Live',Test_orig)
# Out:
# # imgLive: 1000
# Numero di predizioni Live giuste: 842
# Accuracy : 84.2

# %% [markdown]
# dopo

# %%
accuracy_class('Live',Test_p)
# Out:
# # imgLive: 0
# Numero di predizioni Live giuste: 0
# Accuracy : nan
# /usr/local/lib/python3.7/dist-packages/ldart/utils.py:244: RuntimeWarning: invalid value encountered in long_scalars
#   print("Accuracy : "+str(round(n_class/n*100,2)))

# %% [markdown]
# ####numero img spoof predette live con prob >70%

# %%
p=Test_p.loc[Test_p['real']=='Spoof']
p=p.loc[p['predicted']=='Live']
print("img spoof-live: "+str(p.count(0)[0]))
p=p.loc[p['prob_live']>=0.7]
print("img con prob_live>70%: "+str(p.count(0)[0]))

# %% [markdown]
# ##subplot

# %% [markdown]
# ###test finale

# %%
#da usare nel test finale
preds_orig=Test_orig[1500:].predicted.values[list_print]
print(preds_orig)
print_subplot(perturb_print,x_print,y_print,preds_orig,x_print_adv,y_print_adv)

# %% [markdown]
# ###dataset ridotto

# %%
#da usare solo con dataset ridotto
preds_orig=[]
for input,_ in testgen:
  preds_orig_i,_,_=test_average(classifier,input,transf_init)
  preds_orig.append(preds_orig_i)
preds_orig=np.array(preds_orig)
preds_orig=preds_orig[list_print]
preds_orig=np.array([classes_name[i] for i in preds_orig])
print_subplot(perturb_print,x_print,y_print,preds_orig,x_print_adv,y_print_adv) #65.41%
# Out:
# IMMAGINE  0

# %% [markdown]
# #salvataggio e lettura immagine

# %%
save_read(x_print_adv[0],classifier,transf_init)
# Out:
# valori img originale:
# (0, array([0.96655357, 0.0334465 ], dtype=float32), [1.6125759124755858, -1.7512134984135628])
# valori dopo salvataggio/lettura:
# (0, array([0.96782225, 0.03217773], dtype=float32), [1.6327159792184829, -1.7710578382015227])

# %% [markdown]
# #Prova

# %%
Test_en= pd.DataFrame()

path_adv='/content/gdrive/MyDrive/GreenBit_attacks/GreenBit_IFGSM_adv/'
import os
i=0
Directory = os.listdir(path_adv)
for input in Directory:
  i+=1
  sys.stdout.write("\rElem: {0}/{1}".format(i,len(Directory)))
  sys.stdout.flush()
  if input.endswith('.png'):  
    img = cv2.imread(path_adv + input)#.transpose(2,0,1)
    img=(img/255).astype('float32')
    img=enhanc(img,[img.shape[0],img.shape[1]])
    pred,probabilities,_=test_average(classifier,img,transf_init)
    Test_en = Test_en.append({'real': 'Spoof' ,
                          'predicted': classes_name[pred], #qui metti pred
                          'prob_live': round(probabilities[0],4),
                          'prob_spoof': round(probabilities[1],4)},ignore_index = True)
print_acc(Test_en)
# Out:
# Elem: 247/247
# Accuracy: 89.47
# Shape dataframe: (247, 4)
